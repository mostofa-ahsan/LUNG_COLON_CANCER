# %%
import os
os.chdir("C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/")
print(f"Current working directory: {os.getcwd()}")
# os.chdir("C:\Users\mkahs\Repository\lung-cancer-tissue-classification-master\lung-cancer-tissue-classification-master\lung_colon_image_set/colon_image_sets")
# Out:
# Current working directory: C:\Users\mkahs\Repository\lung-cancer-tissue-classification-master\lung-cancer-tissue-classification-master

# %%
# import zipfile
# import os 

# with zipfile.ZipFile("dataset.zip", 'r') as zip_ref:
#     if not os.path.exists("dataset"):
#       zip_ref.extractall("./dataset")
# print("Dataset has been extracted")

# %%
curr_dir="C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/"
original_dataset_dir = os.path.join(curr_dir,"lung_colon_image_set/")
print(original_dataset_dir )
# Out:
# C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/

# %%
training_set_dir=os.path.join(original_dataset_dir ,"dataset/training").replace("\\","/")
validation_set_dir =os.path.join(original_dataset_dir ,"dataset/validation").replace("\\","/")
testing_set_dir =os.path.join(original_dataset_dir ,"dataset/testing").replace("\\","/")

# %%
print(training_set_dir)
# Out:
# C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/training

# %%
# original_dataset_dir = os.path.join(os.getcwd,"lung_colon_image_set/lung_colon_image_set")
# training_set_dir = "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/training"
# validation_set_dir = "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/validation"
# testing_set_dir = "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/testing"


try:
    os.mkdir(training_set_dir)
except FileExistsError:
    print(f"Directory: {training_set_dir} has already been created!")

try:
    os.mkdir(validation_set_dir)
except FileExistsError:
    print(f"Directory: {validation_set_dir} has already been created!")

try:
    os.mkdir(testing_set_dir)
except FileExistsError:
    print(f"Directory: {testing_set_dir} has already been created!")

# %%
import shutil

 
def create_sets(file_format, rngs, rnge, source_dir, destination_dir):

  
  fnames = [f'{file_format}'.format(i) for i in range(rngs, rnge)]

   
  for fname in fnames:
    src = os.path.join(source_dir, fname)  
    dst = os.path.join(destination_dir, fname)  
      
    if not os.path.exists(dst):
          
        shutil.copyfile(src, dst)

# %%
file_formats = {os.path.join(original_dataset_dir, "colon_image_sets/colon_aca"):"colonca{}.jpeg" , 
                os.path.join(original_dataset_dir, "colon_image_sets/colon_n"): "colonn{}.jpeg", 
                os.path.join(original_dataset_dir, "lung_image_sets/lung_aca"): "lungaca{}.jpeg", 
                os.path.join(original_dataset_dir, "lung_image_sets/lung_n"): "lungn{}.jpeg" , 
                os.path.join(original_dataset_dir,"lung_image_sets/lung_scc") : "lungscc{}.jpeg"}

# %%
file_formats
# Out:
# {'C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/colon_image_sets/colon_aca': 'colonca{}.jpeg',
#  'C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/colon_image_sets/colon_n': 'colonn{}.jpeg',
#  'C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/lung_image_sets/lung_aca': 'lungaca{}.jpeg',
#  'C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/lung_image_sets/lung_n': 'lungn{}.jpeg',
#  'C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/lung_image_sets/lung_scc': 'lungscc{}.jpeg'}

# %%
###Class List
class_list=["colon_aca", "colon_n", "lung_aca", "lung_n", "lung_scc" ]

for i in class_list:
    train_dir=os.path.join(training_set_dir,i).replace("\\","/")
    test_dir=os.path.join(testing_set_dir,i).replace("\\","/")
    val_dir=os.path.join(validation_set_dir,i).replace("\\","/")
    
    print(train_dir)
    print(test_dir)
    print(val_dir)
    try:
        os.mkdir(train_dir)
    except FileExistsError:
        print(f"Training dir : {train_dir}... has already been created!")
    try:
        os.mkdir(test_dir)
    except FileExistsError:
        print(f"Testing dir : {test_dir}... has already been created!")
    try:
        os.mkdir(val_dir)
    except FileExistsError:
        print(f"Validation dir : {val_dir}... has already been created!")  



###Training directory


###Testing Directory


###Validation Directory
# Out:
# C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/training/colon_aca
# C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/testing/colon_aca
# C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/validation/colon_aca
# Training dir : C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/training/colon_aca... has already been created!
# Testing dir : C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/testing/colon_aca... has already been created!
# ...

# %%
### Copy data to training folder

for k, v in file_formats.items():
    if v == "colonca{}.jpeg":
        create_sets(v, 1, 2501, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/training/colon_aca")  
    elif v == "colonn{}.jpeg":
        create_sets(v, 1, 2501, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/training/colon_n")
    elif v == "lungaca{}.jpeg":
        create_sets(v, 1, 2501, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/training/lung_aca")
    elif v == "lungn{}.jpeg":
        create_sets(v, 1, 2501, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/training/lung_n")
    else:
        create_sets(v, 1, 2501, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/training/lung_scc")

# %%
### Copy data to testing folder

for k, v in file_formats.items():
    if v == "colonca{}.jpeg":
        create_sets(v, 2501, 3751, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/testing/colon_aca")  
    elif v == "colonn{}.jpeg":
        create_sets(v, 2501, 3751, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/testing/colon_n")
    elif v == "lungaca{}.jpeg":
        create_sets(v, 2501, 3751, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/testing/lung_aca")
    elif v == "lungn{}.jpeg":
        create_sets(v, 2501, 3751, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/testing/lung_n")
    else:
        create_sets(v, 2501, 3751, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/testing/lung_scc")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8928/755040073.py in <module>
#       1 ### Copy data to testing folder
#       2
# ----> 3 for k, v in file_formats.items():
#       4     if v == "colonca{}.jpeg":
#       5         create_sets(v, 2501, 3751, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/testing/colon_aca")
#
# NameError: name 'file_formats' is not defined

# %%
### Copy data to validation folder

for k, v in file_formats.items():
    if v == "colonca{}.jpeg":
        create_sets(v, 3751, 5001, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/validation/colon_aca")  
    elif v == "colonn{}.jpeg":
        create_sets(v, 3751, 5001, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/validation/colon_n")
    elif v == "lungaca{}.jpeg":
        create_sets(v, 3751, 5001, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/validation/lung_aca")
    elif v == "lungn{}.jpeg":
        create_sets(v, 3751, 5001, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/validation/lung_n")
    else:
        create_sets(v, 3751, 5001, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/validation/lung_scc")

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# Λίστα με τα μονοπάτια των εικόνων που θα απεικονιστούν. 
# Υπάρχει μία εικόνα για κάθε κλάση
SAMPLES = ['C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/training/lung_scc/lungscc1.jpeg', 
           'C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/training/lung_n/lungn2.jpeg', 
           'C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/training/lung_aca/lungaca3.jpeg', 
           'C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/training/colon_n/colonn4.jpeg', 
           'C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/training/colon_aca/colonca5.jpeg']

# όρισε το μέγεθος του γραφήματος
plt.figure(figsize=(22, 8)) 

global c
c = 0

# Εμφάνισε τις 5 εικόνες, την μία δίπλα στην άλλη
for i in SAMPLES:
    plt.subplot(1, 5, c + 1)
    c += 1
    t = i.split('/')
    plt.title(t[3])
    plt.imshow(image.load_img(i))
    plt.axis('off')
plt.show()

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential

# %%
img_width = 256  
img_height = 256  
batch_size = 128

# %%
train_datagen = ImageDataGenerator(rescale = 1/255.0, 
                                   rotation_range=30,  
                                   zoom_range=0.4, 
                                   horizontal_flip=True  
                                   )


train_generator = train_datagen.flow_from_directory(training_set_dir,  
                                                    batch_size=batch_size, 
                                                    class_mode='categorical',  
                                                    target_size=(img_height, img_width)  
                                                    )
# Out:
# Found 12500 images belonging to 5 classes.

# %%
validation_datagen = ImageDataGenerator(rescale = 1/255.0)

validation_generator = validation_datagen.flow_from_directory(validation_set_dir,
                                                              batch_size=batch_size,
                                                              class_mode='categorical',
                                                              target_size=(img_height, img_width)
                                                             )
# Out:
# Found 6250 images belonging to 5 classes.

# %%
model = Sequential([
    
    
    Conv2D(16,  
           (3, 3), 
           activation='relu',  
           input_shape=(img_height, img_width, 3)), 

    
    MaxPooling2D(2, 2), 
    
    
    Conv2D(32, 
           (3, 3), 
           activation='relu'), 

   
    MaxPooling2D(2, 2),  

    
    Conv2D(64, 
           (3, 3), 
           activation='relu'),

    
    Conv2D(64, 
           (3, 3), 
           activation='relu'),

    
    MaxPooling2D(2, 2),  

    
    Conv2D(128, 
           (3, 3), 
           activation='relu'),

    
    Conv2D(128, 
           (3, 3), 
           activation='relu'),

    
    MaxPooling2D(2, 2),  

    
    Conv2D(256, 
           (3, 3), 
           activation='relu'),

    
    Conv2D(256, 
           (3, 3), 
           activation='relu'),

    
    Conv2D(256, 
           (3, 3), 
           activation='relu'),

    
    MaxPooling2D(2, 2),  

    
    Flatten(),  

    
    Dense(512, 
          activation='relu'),

    
    Dense(512, 
          activation='relu'),

    
    Dense(5,  
          activation='softmax')  
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 58, 58, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 29, 29, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 27, 27, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 10, 10, 256)       295168
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 256)         590080
#
# ...

# %%
model.compile(optimizer='Adam', 
              loss='categorical_crossentropy', 
              metrics =['accuracy'])

# %%
history = model.fit(train_generator,  
                epochs=30,  
                verbose=1,  
                validation_data=validation_generator  
                )
# Out:
# Epoch 1/30
# 98/98 [==============================] - 212s 2s/step - loss: 1.2656 - accuracy: 0.3743 - val_loss: 0.6797 - val_accuracy: 0.6688
# Epoch 2/30
# 98/98 [==============================] - 195s 2s/step - loss: 0.6000 - accuracy: 0.7286 - val_loss: 0.5591 - val_accuracy: 0.7387
# Epoch 3/30
# 98/98 [==============================] - 197s 2s/step - loss: 0.4636 - accuracy: 0.8038 - val_loss: 0.3993 - val_accuracy: 0.8325
# Epoch 4/30
# 98/98 [==============================] - 195s 2s/step - loss: 0.4292 - accuracy: 0.8142 - val_loss: 0.3707 - val_accuracy: 0.8459
# Epoch 5/30
# 98/98 [==============================] - 191s 2s/step - loss: 0.3813 - accuracy: 0.8368 - val_loss: 0.3201 - val_accuracy: 0.8616
# Epoch 6/30
# 98/98 [==============================] - 200s 2s/step - loss: 0.3307 - accuracy: 0.8596 - val_loss: 0.3036 - val_accuracy: 0.8637
# Epoch 7/30
# ...

# %%
# import tensorflow
# tensorflow.saved_model.save(model, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/model_30_type_1")
# Out:
# INFO:tensorflow:Assets written to: C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/model_30_type_1\assets

# %%
tensorflow.keras.models.save_model(
    model,
    filepath="C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/model_30_type_2",
    overwrite=True,
    include_optimizer=True,
    save_format=None,
    signatures=None,
    options=None,
    save_traces=True
)
# Out:
# INFO:tensorflow:Assets written to: C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/model_30_type_2\assets

# %%
import numpy as np
from keras.preprocessing.image import load_img, img_to_array


def preprocess_image(path):
    img = load_img(path, target_size = (img_height, img_width))
    a = img_to_array(img)  
    a = np.expand_dims(a, axis = 0)  
    a /= 255.  
    return a

# %%
import pandas as pd
test_images_dir = 'C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/test_images/'
test_df = pd.read_csv('C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/labels.csv')



test_dfToList = test_df['Image_id'].tolist()
test_ids = [str(item) for item in test_dfToList]


test_images = [test_images_dir+item for item in test_ids]


prep_imgs = [preprocess_image(fn) for fn in test_images]


test_preprocessed_images = np.vstack(prep_imgs)

# %%
array = model.predict(test_preprocessed_images, batch_size=1, verbose=1)


answer = np.argmax(array, axis=1)
# Out:
# 6250/6250 [==============================] - 20s 3ms/step

# %%
test_df = pd.read_csv('C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/labels.csv')


y_true = test_df['labels']

# %%
import sklearn.metrics


test_accuracy_nn = sklearn.metrics.accuracy_score(y_true, answer)

print("The Accuracy of the Neural Network on the Test Data is", test_accuracy_nn)
# Out:
# The Accuracy of the Neural Network on the Test Data is 0.9784

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd
image_folders = ['colon_aca', 'colon_n', 'lung_aca', 'lung_n', 'lung_scc']

df = pd.DataFrame({"Y_Actual": y_true, 
                  "Y_Predicted": answer 
                  }
                 )


conf_mat = pd.crosstab(df["Y_Actual"], 
                       df["Y_Predicted"], 
                       rownames=["Actual"],
                       colnames=["Predicted"],
                       margins=True 
                      )  

print(f"The confusion matrix of the classification is: \n{conf_mat}")
print("-"*71)


conf_mat = conf_mat.drop("All", axis=0) 
conf_mat = conf_mat.drop("All", axis=1) 


f, axis = plt.subplots(nrows=1, ncols=1, figsize=(10, 6)) 
sns.heatmap(conf_mat,
            annot=True, 
            fmt="d", 
            cmap="YlGnBu", 
            ax=axis, 
            xticklabels=image_folders,
            yticklabels=image_folders
            )
axis.set_xlabel("\nPredicted Class")
axis.set_ylabel("Actual Class")
axis.set_title("The Confusion Matrix of the Classification \n on the Test Data")

plt.show()
# Out:
# The confusion matrix of the classification is:
# Predicted     0     1     2     3     4   All
# Actual
# 0          1212    35     2     1     0  1250
# 1             1  1249     0     0     0  1250
# 2             0     1  1198     0    51  1250
# 3             0     0    16  1234     0  1250
# 4             0     0    28     0  1222  1250
# All        1213  1285  1244  1235  1273  6250
# -----------------------------------------------------------------------

# %%
answer
# Out:
# array([0, 0, 0, ..., 4, 4, 4], dtype=int64)

# %%
test_df['preds']=answer
test_df.head()
# Out:
#    Unnamed: 0          Image_id  labels  preds
# 0           0  colonca2501.jpeg       0      0
# 1           1  colonca2502.jpeg       0      0
# 2           2  colonca2503.jpeg       0      0
# 3           3  colonca2504.jpeg       0      0
# 4           4  colonca2505.jpeg       0      0

# %%
test_df.to_csv('C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/Preds_30.csv')

# %%
import tensorflow_text as text
imported_30_type_1 = tensorflow.saved_model.load("C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/model_30_type_1")

# %%
# array = imported_30_type_1.predict(test_preprocessed_images, batch_size=1, verbose=1)


# loaded_answer_type_1 = np.argmax(array, axis=1)

# %%
import tensorflow_text as text
imported_30_type_2 = tensorflow.keras.models.load_model("C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/model_30_type_2")

# %%
array = imported_30_type_2.predict(test_preprocessed_images, batch_size=64, verbose=1)
# Out:
# 98/98 [==============================] - 5s 42ms/step

# %%
loaded_answer_type_2 = np.argmax(array, axis=1)

# %%
import sklearn.metrics


test_accuracy_nn = sklearn.metrics.accuracy_score(y_true, answer)

print("The Accuracy of the Neural Network on the Test Data is", test_accuracy_nn)
# Out:
# The Accuracy of the Neural Network on the Test Data is 0.9784

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd
image_folders = ['colon_aca', 'colon_n', 'lung_aca', 'lung_n', 'lung_scc']

df = pd.DataFrame({"Y_Actual": y_true, 
                  "Y_Predicted": answer 
                 )


conf_mat = pd.crosstab(df["Y_Actual"], 
                       df["Y_Predicted"], 
                       rownames=["Actual"], 
                       colnames=["Predicted"], 
                       margins=True 
                      )  

print(f"The confusion matrix of the classification is: \n{conf_mat}")
print("-"*71)


conf_mat = conf_mat.drop("All", axis=0) 
conf_mat = conf_mat.drop("All", axis=1) 


f, axis = plt.subplots(nrows=1, ncols=1, figsize=(10, 6)) 
sns.heatmap(conf_mat, 
            annot=True, 
            fmt="d",
            cmap="YlGnBu", 
            ax=axis, 
            xticklabels=image_folders,
            yticklabels=image_folders
            )
axis.set_xlabel("\nPredicted Class")
axis.set_ylabel("Actual Class")
axis.set_title("The Confusion Matrix of the Classification \n on the Test Data")

plt.show()
# Out:
# The confusion matrix of the classification is:
# Predicted     0     1     2     3     4   All
# Actual
# 0          1212    35     2     1     0  1250
# 1             1  1249     0     0     0  1250
# 2             0     1  1198     0    51  1250
# 3             0     0    16  1234     0  1250
# 4             0     0    28     0  1222  1250
# All        1213  1285  1244  1235  1273  6250
# -----------------------------------------------------------------------

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc))

fig = plt.figure(figsize=(14,7))
plt.plot(epochs, acc, 'r', label="Training Accuracy")
plt.plot(epochs, val_acc, 'b', label="Validation Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
fig2 = plt.figure(figsize=(14,7))
plt.plot(epochs, loss, 'r', label="Training Loss")
plt.plot(epochs, val_loss, 'b', label="Validation Loss")
plt.legend(loc='upper right')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
### Load model

imported_30_type_1 = tensorflow.saved_model.load(path="C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/model_30_type_1")
imported_30_type_2 = tensorflow.keras.models.load_model("C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/model_30_type_2")

# %%
history_60 = model.fit(train_generator,  
                epochs=60,  
                verbose=1,  
                validation_data=validation_generator  
                )
# Out:
# Epoch 1/60
# 98/98 [==============================] - 195s 2s/step - loss: 0.0785 - accuracy: 0.9698 - val_loss: 0.0949 - val_accuracy: 0.9646
# Epoch 2/60
# 98/98 [==============================] - 190s 2s/step - loss: 0.0815 - accuracy: 0.9707 - val_loss: 0.0691 - val_accuracy: 0.9718
# Epoch 3/60
# 98/98 [==============================] - 189s 2s/step - loss: 0.1036 - accuracy: 0.9649 - val_loss: 0.0956 - val_accuracy: 0.9632
# Epoch 4/60
# 98/98 [==============================] - 190s 2s/step - loss: 0.0752 - accuracy: 0.9746 - val_loss: 0.0760 - val_accuracy: 0.9749
# Epoch 5/60
# 98/98 [==============================] - 190s 2s/step - loss: 0.0825 - accuracy: 0.9690 - val_loss: 0.0773 - val_accuracy: 0.9691
# Epoch 6/60
# 98/98 [==============================] - 191s 2s/step - loss: 0.0755 - accuracy: 0.9746 - val_loss: 0.0394 - val_accuracy: 0.9861
# Epoch 7/60
# ...

# %%
tensorflow.keras.models.save_model(
    model,
    filepath="C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/model_60_type_2",
    overwrite=True,
    include_optimizer=True,
    save_format=None,
    signatures=None,
    options=None,
    save_traces=True
)
# Out:
# INFO:tensorflow:Assets written to: C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/model_60_type_2\assets

# %%
array = model.predict(test_preprocessed_images, batch_size=1, verbose=1)

answer_2 = np.argmax(array, axis=1)
# Out:
# 6250/6250 [==============================] - 19s 3ms/step

# %%
import sklearn.metrics


test_accuracy_nn = sklearn.metrics.accuracy_score(y_true, answer_2)

print("The Accuracy of the Neural Network on the Test Data is", test_accuracy_nn)
# Out:
# The Accuracy of the Neural Network on the Test Data is 0.99392

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc))

fig = plt.figure(figsize=(14,7))
plt.plot(epochs, acc, 'r', label="Training Accuracy")
plt.plot(epochs, val_acc, 'b', label="Validation Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
fig2 = plt.figure(figsize=(14,7))
plt.plot(epochs, loss, 'r', label="Training Loss")
plt.plot(epochs, val_loss, 'b', label="Validation Loss")
plt.legend(loc='upper right')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
### Copy data to testing folder

for k, v in file_formats.items():
    if v == "colonca{}.jpeg":
        create_sets(v, 2501, 3751, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/test_images")  
    elif v == "colonn{}.jpeg":
        create_sets(v, 2501, 3751, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/test_images")
    elif v == "lungaca{}.jpeg":
        create_sets(v, 2501, 3751, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/test_images")
    elif v == "lungn{}.jpeg":
        create_sets(v, 2501, 3751, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/test_images")
    else:
        create_sets(v, 2501, 3751, k, "C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/test_images")

# %%
# Εισαγωγή της βιβλιοθήκης pandas με το ψευδώνυμο pd
import pandas as pd


# Δημιουργία της λίστα που θα περιέχει τις ετικέτες των εικόνων, 
# όπως οι τελευταίες συναντώνται μέσα στον φάκελο "test_images/"
label_list = []
# "colon_aca", "colon_n", "lung_aca", "lung_n", "lung_scc" 
# Δημιουργία λεξικού με κλειδιά τις κλάσεις και τιμές το είδος των εικόνων.
classes_classification = {0: "colonca", 
                          1: "colonn", 
                          2: "lungaca", 
                          3: "lungn", 
                          4: "lungscc"}

# Δημιούργησε μια λίστα με τα ονόματα των αρχείων (εικόνες) που βρίσκονται μέσα 
# στον φάκελο "test_images/"
# m="C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/test_images"
image_id = [i for i in os.listdir("C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/test_images")]

# Αποθήκευσε τις σωστές ετικέτες στην λίστα 
label_list = [k for i in image_id for k, v in classes_classification.items() if v in i ]

# Δημιούργησε ένα DataFrame, με στήλες τα ονόματα των αρχείων και τις 
# αντίστοιχες ετικέτες τους
labels = {
  'Image_id': image_id,
  'labels': label_list
}

df = pd.DataFrame(labels)

# Αποθήκευσε το DataFrame στο αρχείο με όνομα "labels.csv"
df.to_csv("C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/labels_3.csv")

# %%
df.shape
# Out:
# (6250, 2)

# %%
df.head()
# Out:
#            Image_id  labels
# 0  colonca2501.jpeg       0
# 1  colonca2502.jpeg       0
# 2  colonca2503.jpeg       0
# 3  colonca2504.jpeg       0
# 4  colonca2505.jpeg       0

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# %%
import os 
import pickle
import joblib
import tensorflow_text as text

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from tensorflow.keras.models import load_model

# %%
import numpy as np
from keras.preprocessing.image import load_img, img_to_array

def preprocess_image(path):
    img = load_img(path, target_size = (img_height, img_width))
    a = img_to_array(img)  
    a = np.expand_dims(a, axis = 0)  
    a /= 255.  
    return a

# %%
test_images_dir = 'C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/test_images/'
test_df = pd.read_csv('C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/labels.csv')


test_dfToList = test_df['Image_id'].tolist()
test_ids = [str(item) for item in test_dfToList]


test_images = [test_images_dir+item for item in test_ids]


prep_imgs = [preprocess_image(fn) for fn in test_images]


test_preprocessed_images = np.vstack(prep_imgs)

# %%
array = model.predict(test_preprocessed_images, batch_size=1, verbose=1)


answer = np.argmax(array, axis=1)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15696/201802632.py in <module>
#       1 # Πρόβλεψε τις πιθανότητες  συμμετοχής των εικόνων δοκιμής στις κλάσεις
# ----> 2 array = model.predict(test_preprocessed_images, batch_size=1, verbose=1)
#       3
#       4 # Ανέθεσε την κάθε εικόνα στην κλάση με την μεγαλύτερη πιθανότητα
#       5 answer = np.argmax(array, axis=1)
#
# ~\anaconda3\envs\RTX2080\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ...

# %%
test_df = pd.read_csv('C:/Users/mkahs/Repository/lung-cancer-tissue-classification-master/lung-cancer-tissue-classification-master/lung_colon_image_set/dataset/labels.csv')

y_true = test_df['labels']
